# %% [markdown]
# <a href="https://colab.research.google.com/github/JPatGC/Bias-and-Toxicity/blob/main/Summarization_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# wrap the output in colab cells
from IPython.display import HTML, display

def set_css():
  display(HTML('''

  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# install transformers with sentencepiece
# !pip install transformers[sentencepiece]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.3 MB/s eta 0:00:00
# ...

# %%
# open and read the file from google drive
file = open("https://drive.google.com/drive/folders/1DiaGVTC3QRi1PMvubH3eixjNS7Cf5FDi.txt", "r")
FileContent = file.read().strip()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-fed3e5acef9f> in <cell line: 2>()
#       1 # open and read the file from google drive
# ----> 2 file = open("https://drive.google.com/drive/folders/1DiaGVTC3QRi1PMvubH3eixjNS7Cf5FDi.txt", "r")
#       3 FileContent = file.read().strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://drive.google.com/drive/folders/1DiaGVTC3QRi1PMvubH3eixjNS7Cf5FDi.txt'

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Specify the folder path
folder_path = 'file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'

# Change the current working directory to the folder path
import os
os.chdir(drive/folders/1DiaGVTC3QRi1PMvubH3eixjNS7Cf5FDi?usp=share_link)
# Out:
#   File "<ipython-input-23-712934a7534e>", line 6
#     os.chdir(drive/folders/1DiaGVTC3QRi1PMvubH3eixjNS7Cf5FDi?usp=share_link)
#                            ^
# SyntaxError: invalid decimal literal

# %%
# Specify the text file name
text_file_name = 'Chopin A Night in Acadie (1).txt'

# Full path to the text file
text_file_path = os.path.join(folder_path, text_file_name)

# %%
# display file content
FileContent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fe126e8d94cb> in <cell line: 2>()
#       1 # display file content
# ----> 2 FileContent
#
# NameError: name 'FileContent' is not defined

# %%
# Open and read the content of the file
file_path = '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link/Chopin A Night in Acadie (1).txt'

with open(file_path, 'r') as file:
    file_content = file.read()

# Display the content
print(file_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-99dbd671dcb5> in <cell line: 4>()
#       2 file_path = '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link/Chopin A Night in Acadie (1).txt'
#       3
# ----> 4 with open(file_path, 'r') as file:
#       5     file_content = file.read()
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link/Chopin A Night in Acadie (1).txt'

# %%
import sys
import os

from google.colab import drive
drive.mount('/content/gdrive')

path = '/https://drive.google.com/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'
fnames = os.listdir(path)
# Out:
# Mounted at /content/gdrive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-404e98f392c4> in <cell line: 8>()
#       6
#       7 path = '/https://drive.google.com/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'
# ----> 8 fnames = os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/https://drive.google.com/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'

# %%
import sys
import os

from google.colab import drive
drive.mount('/content/gdrive')

path = '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'
fnames = os.listdir(path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7a360b059729> in <cell line: 8>()
#       6
#       7 path = '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'
# ----> 8 fnames = os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/file/d/1bIJiCe_eNEJR6rn4F9XfX_YrT-H9EUqF/view?usp=share_link'

# %%
# !pip install hyperas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.6 MB/s eta 0:00:00
# ...

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title='notebook.ipynb'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('notebook.ipynb')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-efa53879d6b6> in <cell line: 15>()
#      13
#      14 # Copy/download the file
# ---> 15 fid = drive.ListFile({'q':"title='notebook.ipynb'"}).GetList()[0]['id']
#      16 f = drive.CreateFile({'id': fid})
#      17 f.GetContentFile('notebook.ipynb')
#
# IndexError: list index out of range

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title= Chopin At Fault.txt'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('Chopin At Fault.txt')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-5-a71e298d5b9c> in <cell line: 15>()
#      13
#      14 # Copy/download the file
# ---> 15 fid = drive.ListFile({'q':"title= Chopin At Fault.txt'"}).GetList()[0]['id']
#      16 f = drive.CreateFile({'id': fid})
#      17 f.GetContentFile('Chopin At Fault.txt')
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in GetList(self)
#     160       self['maxResults'] = 1000
#     161       result = []
# --> 162       for x in self:
#     163         result.extend(x)
#     164       del self['maxResults']
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in __next__(self)
#     144     if 'pageToken' in self and self['pageToken'] is None:
#     145       raise StopIteration
# --> 146     result = self._GetList()
#     147     self['pageToken'] = self.metadata.get('nextPageToken')
# ...

# %%
title='Chopin At Fault.txt'

# %%
q = "title='Chopin At Fault.txt'"

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title= Chopin At Fault.txt'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('Chopin At Fault.txt')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-3-a71e298d5b9c> in <cell line: 15>()
#      13
#      14 # Copy/download the file
# ---> 15 fid = drive.ListFile({'q':"title= Chopin At Fault.txt'"}).GetList()[0]['id']
#      16 f = drive.CreateFile({'id': fid})
#      17 f.GetContentFile('Chopin At Fault.txt')
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in GetList(self)
#     160       self['maxResults'] = 1000
#     161       result = []
# --> 162       for x in self:
#     163         result.extend(x)
#     164       del self['maxResults']
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in __next__(self)
#     144     if 'pageToken' in self and self['pageToken'] is None:
#     145       raise StopIteration
# --> 146     result = self._GetList()
#     147     self['pageToken'] = self.metadata.get('nextPageToken')
# ...

# %%
q = "title='Chopin At Fault.txt'"

# %%
# Copy/download the file
file_list = drive.ListFile({'q': "title='Chopin At Fault.txt'"}).GetList()
if file_list:
    fid = file_list[0]['id']
    f = drive.CreateFile({'id': fid})
    f.GetContentFile('Chopin At Fault.txt')
    print('File downloaded successfully!')
else:
    print('File not found in Google Drive.')
# Out:
# File downloaded successfully!

# %%
# display file content
FileContent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fe126e8d94cb> in <cell line: 2>()
#       1 # display file content
# ----> 2 FileContent
#
# NameError: name 'FileContent' is not defined

# %%
# Assuming you've successfully downloaded the file
with open('Chopin At Fault.txt', 'r') as file:
    file_content = file.read()

# Now you can use the variable file_content
print(file_content)
# Out:
# At Fault
#
# by Kate Chopin
#
#
#
#
# Part I.
#
#      I. The Mistress of Place-du-Bois.
#     II. At the Mill.
#    III. In the Pirogue.
#     IV. A Small Interruption.
#      V. In the Pine Woods.
#     VI. Melicent Talks.
#    VII. Painful Disclosures.
#   VIII. Treats of Melicent.
#     IX. Face to Face.
#      X. Fanny's Friends.
#     XI. The Self-Assumed Burden.
#    XII. Severing Old Ties.
#
#
# Part II.
#
#      I. Fanny's First Night at Place-du-Bois.
#     II. "Neva to See You!"
#    III. A Talk Under the Cedar Tree.
#     IV. Thérèse Crosses the River.
#      V. One Afternoon.
#     VI. One Night.
#    VII. Melicent Leaves Place-du-Bois.
#   VIII. With Loose Rein.
#     IX. The Reason Why.
#      X. Perplexing Things.
#     XI. A Social Evening.
#    XII. Tidings That Sting.
#   XIII. Melicent Hears the News.
#    XIV. A Step Too Far.
#     XV. A Fateful Solution.
#    XVI. To Him Who Waits.
#   XVII. Conclusion.
#
#
#
#
# PART I
#
#
#
#
# I
#
# ...

# %%
# total characters in the file
len(FileContent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bdb168adba28> in <cell line: 2>()
#       1 # total characters in the file
# ----> 2 len(FileContent)
#
# NameError: name 'FileContent' is not defined

# %%
# Assuming you've successfully downloaded the file and read its content
with open('Chopin At Fault.txt', 'r') as file:
    file_content = file.read()

# Calculate the total number of characters
total_characters = len(file_content)

# Print the result
print(f'Total characters in the file: {total_characters}')
# Out:
# Total characters in the file: 325676

# %%
# import and initialize the tokenizer and model from the checkpoint
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

checkpoint = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]

# %%
# max tokens including the special tokens
tokenizer.model_max_length
# Out:
# 1024

# %%
# max tokens excluding the special tokens
tokenizer.max_len_single_sentence
# Out:
# 1022

# %%
# number of special tokens
tokenizer.num_special_tokens_to_add()
# Out:
# 2

# %%
# extract the sentences from the document
import nltk
nltk.download('punkt')
sentences = nltk.tokenize.sent_tokenize(FileContent)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dbaf01ba08e2> in <cell line: 4>()
#       2 import nltk
#       3 nltk.download('punkt')
# ----> 4 sentences = nltk.tokenize.sent_tokenize(FileContent)
#
# NameError: name 'FileContent' is not defined

# %%
import nltk
nltk.download('punkt')

# Assuming you've successfully downloaded the file and read its content
with open('Chopin At Fault.txt', 'r') as file:
    file_content = file.read()

# Tokenize the sentences
sentences = nltk.sent_tokenize(file_content)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# find the max tokens in the longest sentence
max([len(tokenizer.tokenize(sentence)) for sentence in sentences])
# Out:
# 109

# %%
# initialize
length = 0
chunk = ""
chunks = []
count = -1
for sentence in sentences:
  count += 1
  combined_length = len(tokenizer.tokenize(sentence)) + length # add the no. of sentence tokens to the length counter

  if combined_length  <= tokenizer.max_len_single_sentence: # if it doesn't exceed
    chunk += sentence + " " # add the sentence to the chunk
    length = combined_length # update the length counter

    # if it is the last sentence
    if count == len(sentences) - 1:
      chunks.append(chunk.strip()) # save the chunk

  else:
    chunks.append(chunk.strip()) # save the chunk

    # reset
    length = 0
    chunk = ""

    # take care of the overflow sentence
    chunk += sentence + " "
    length = len(tokenizer.tokenize(sentence))
len(chunks)
# Out:
# 83

# %%
[len(tokenizer.tokenize(c)) for c in chunks]
# Out:
# [965,
#  1000,
#  1000,
#  1006,
#  1009,
#  983,
#  994,
#  1010,
#  996,
#  1007,
#  995,
#  1016,
#  978,
#  1014,
#  993,
#  991,
#  1012,
#  1014,
#  998,
#  1022,
#  1014,
#  1017,
#  993,
#  988,
#  1015,
#  988,
#  1007,
#  1003,
#  1014,
#  1013,
#  1005,
#  961,
#  1014,
#  1001,
#  1017,
#  978,
#  998,
#  1014,
#  987,
#  985,
#  986,
#  988,
#  1018,
#  1010,
#  999,
#  1011,
#  1007,
#  1015,
#  997,
#  991,
#  1021,
#  1006,
#  1002,
#  1013,
#  957,
#  1018,
#  971,
#  998,
#  990,
#  991,
#  1012,
#  985,
#  1018,
#  1007,
#  1014,
#  996,
#  1001,
#  1003,
#  1017,
#  1018,
#  1007,
#  998,
#  1013,
#  1011,
#  1015,
#  1016,
#  1016,
#  962,
#  1010,
#  1008,
#  996,
#  1008,
#  108]

# %%
[len(tokenizer(c).input_ids) for c in chunks]
# Out:
# [967,
#  1002,
#  1002,
#  1008,
#  1011,
#  985,
#  996,
#  1012,
#  998,
#  1009,
#  997,
#  1018,
#  980,
#  1016,
#  995,
#  993,
#  1014,
#  1016,
#  1000,
#  1024,
#  1016,
#  1019,
#  995,
#  990,
#  1017,
#  990,
#  1009,
#  1005,
#  1016,
#  1015,
#  1007,
#  963,
#  1016,
#  1003,
#  1019,
#  980,
#  1000,
#  1016,
#  989,
#  987,
#  988,
#  990,
#  1020,
#  1012,
#  1001,
#  1013,
#  1009,
#  1017,
#  999,
#  993,
#  1023,
#  1008,
#  1004,
#  1015,
#  959,
#  1020,
#  973,
#  1000,
#  992,
#  993,
#  1014,
#  987,
#  1020,
#  1009,
#  1016,
#  998,
#  1003,
#  1005,
#  1019,
#  1020,
#  1009,
#  1000,
#  1015,
#  1013,
#  1017,
#  1018,
#  1018,
#  964,
#  1012,
#  1010,
#  998,
#  1010,
#  110]

# %%
sum([len(tokenizer(c).input_ids) for c in chunks])
# Out:
# 82409

# %%
# inputs to the model
inputs = [tokenizer(chunk, return_tensors="pt") for chunk in chunks]

# %%
for input in inputs:
  output = model.generate(**input)
  print(tokenizer.decode(*output, skip_special_tokens=True))
# Out:
#  At Fault by Kate Chopin: The Mistress of Place-du-Bois. The Creole widow of thirty. She lived alone with her grief; shutting out the.comeals that came to her from the demoralized "hands" of her husband Jérôme Lafirme. She felt at once the weight and sacredness of a trust brought consolation and awakened unsuspected powers of.doing.
#  Jérôme Lafirme's death drove Thérèse to seek another domicile. The old homestead that nestled to the hill side and close to the river's edge, had been abandoned. The railroad brought soon after his death was viewed by many as of questionable benefit.
#  David Hosmer had come to Mrs. Lafirme on the land with a moneyed offer for the privilege of cutting timber from her land for a given number of years. The company which he represented had in view the erection of a sawmill two miles back in the woods, close beside the bayou and at a convenient distance from the lake. The mill's unceasing buzz made pleasant music to his ears.
# ...
